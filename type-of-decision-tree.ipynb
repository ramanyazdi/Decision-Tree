# %% [markdown]
# <p style="font-size: 60px; text-align: center;">Decision Tree Types</p>

# %% [markdown]
# ![Untitled.png](attachment:83fdc5c2-6f12-4ff6-bcce-61110b7a79df.png)

# %% [markdown]
# ![Untitled.png](attachment:e8f81664-8e39-4201-925c-9ff9591ded02.png)

# %% [markdown]
# ![Untitled.png](attachment:f890805b-d6d0-4b8a-be29-ce5b3d6c571a.png)

# %% [markdown]
# ![Untitled.png](attachment:9600f71d-c86f-4600-8e49-a20794e2e932.png)

# %% [markdown]
# Source: StatQuest
